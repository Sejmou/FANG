# %% [markdown]
# # Running [FANG](https://github.com/nguyenvanhoang7398/FANG.git) code in Colab

# %% [markdown]
# This notebook describes how we tried to get the code for FANG to run on Google's Colab instances with GPU. Copy and execute this notebook on Google Colab to reproduce.

# %% [markdown]
# ## 1. Make sure GPU runtime is active (Runtime -> Change runtime type -> Select "GPU")
# ***Note:*** *unfortunately, GPUs are [sometimes not available](https://research.google.com/colaboratory/faq.html#resource-limits) with the free version of Google Colab. In such cases, there's nothing one can do about it except waiting, or paying :(*

# %%
# get details on GPU that is made available to us:
# !nvidia-smi -L
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %% [markdown]
# ## 2. Install conda using [condacolab](https://github.com/conda-incubator/condacolab):
#
# ***Important:*** *Running the cell below will cause the runtime to crash and restart, don't skip to the next cell right away, wait until Colab has restarted.*

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:30
# 🔁 Restarting kernel...

# %% [markdown]
# ## 3. Get code + data from FANG [GitHub repo](https://github.com/nguyenvanhoang7398/FANG.git)

# %% [markdown]
# The best option is probably cloning the repo and uploading the folder to your Google Drive and then mounting your Google Drive:

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Alternatively, you could also upload the whole cloned folder (or any arbitrary version of the code with custom modifications) from your local file system:

# %%
#upload ZIP of repo that has been downloaded to local machine:
#from google.colab import files

#uploaded = files.upload()

#for fn in uploaded.keys():
#  print('Successfully uploaded file "{name}" with length {length} bytes'.format(
#      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-aca25773-c68e-47dc-b70e-f518cb053813" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aca25773-c68e-47dc-b70e-f518cb053813">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving FANG-master.zip to FANG-master.zip
# Successfully uploaded file "FANG-master.zip" with length 51843531 bytes

# %%
# unzip uploaded ZIP (assuming it is called FANG-master.zip)
#!unzip FANG-master.zip
# Out:
# Archive:  FANG-master.zip
# 7addc8e56391922d63986e863925e405c4f1a399
#    creating: FANG-master/
#  extracting: FANG-master/.gitignore
#   inflating: FANG-master/README.md
#    creating: FANG-master/data/
#   inflating: FANG-master/data/fang_fake.csv
#   inflating: FANG-master/data/fang_real.csv
#    creating: FANG-master/data/news_graph/
#   inflating: FANG-master/data/news_graph/deny.tsv
#   inflating: FANG-master/data/news_graph/entities.txt
#   inflating: FANG-master/data/news_graph/entity_features.tsv
#   inflating: FANG-master/data/news_graph/media_factuality.txt
#   inflating: FANG-master/data/news_graph/meta_data.tsv
#   inflating: FANG-master/data/news_graph/news_info.tsv
#   inflating: FANG-master/data/news_graph/rep_entities.tsv
#   inflating: FANG-master/data/news_graph/report.tsv
#   inflating: FANG-master/data/news_graph/source_citation.tsv
#   inflating: FANG-master/data/news_graph/source_publication.tsv
#   inflating: FANG-master/data/news_graph/support_negative.tsv
#   inflating: FANG-master/data/news_graph/support_neutral.tsv
#   inflating: FANG-master/data/news_graph/train_test_10.json
#   inflating: FANG-master/data/news_graph/train_test_30.json
#   inflating: FANG-master/data/news_graph/train_test_50.json
#   inflating: FANG-master/data/news_graph/train_test_70.json
#   inflating: FANG-master/data/news_graph/train_test_90.json
#   inflating: FANG-master/data/news_graph/user_relationships.tsv
#    creating: FANG-master/dataset/
#  extracting: FANG-master/dataset/__init__.py
#   inflating: FANG-master/dataset/news_graph.py
#   inflating: FANG-master/dataset/utils.py
#   inflating: FANG-master/environment.yml
#    creating: FANG-master/fang/
#  extracting: FANG-master/fang/__init__.py
#   inflating: FANG-master/fang/config.py
#   inflating: FANG-master/fang/dataset.py
#    creating: FANG-master/fang/graphsage/
#   inflating: FANG-master/fang/graphsage/__init__.py
#   inflating: FANG-master/fang/graphsage/models.py
#   inflating: FANG-master/fang/graphsage/walker.py
#   inflating: FANG-master/fang/utils.py
#    creating: FANG-master/graph/
#  extracting: FANG-master/graph/__init__.py
#    creating: FANG-master/graph/gcn/
#  extracting: FANG-master/graph/gcn/__init__.py
#   inflating: FANG-master/graph/gcn/layers.py
#    creating: FANG-master/graph/ngcn/
#  extracting: FANG-master/graph/ngcn/__init__.py
#   inflating: FANG-master/graph/ngcn/model.py
#   inflating: FANG-master/run_graph.py
#    creating: FANG-master/training/
#  extracting: FANG-master/training/__init__.py
#   inflating: FANG-master/training/configs.py
#   inflating: FANG-master/training/evaluator.py
#   inflating: FANG-master/training/news_graph.py
#   inflating: FANG-master/training/utils.py
#    creating: FANG-master/user_embed/
#  extracting: FANG-master/user_embed/__init__.py
#    creating: FANG-master/user_embed/graphsage/
#  extracting: FANG-master/user_embed/graphsage/__init__.py
#   inflating: FANG-master/user_embed/graphsage/layers.py
#   inflating: FANG-master/user_embed/graphsage/models.py

# %%
# !ls
# Out:
# FANG-master  FANG-master.zip  sample_data

# %% [markdown]
# Or, clone the repo directly on the Colab instance:

# %%
#!git clone https://github.com/nguyenvanhoang7398/FANG.git

# %% [markdown]
# Disadvantage of both approaches compared to using Google Drive: data created is lost after runtime disconnects - unless you downloaded it beforehand, of course. If you use Google Drive the data should be synced to the folder on Google Drive, ideally saving us training time the next time around as we can use pretrained models created by the FANG script.

# %% [markdown]
# ## 4. Navigate to folder containing FANG code + data

# %% [markdown]
# Make sure to provide the correct path depending on how you loaded data in previous step.

# %%
# %cd 'drive/My Drive/shared/fang'
#%cd 'FANG-master'
# Out:
# /content/drive/.shortcut-targets-by-id/1ToHnZjx6MmCRPAtxDUrirVP51cZnbzgo/fang

# %% [markdown]
# We should now see the FANG code + data:

# %%
# !ls
# Out:
# condacolab_install.log	environment.yml  fang	     README.md	   user_embed
# data			exp_ckpt	 fang.ipynb  run_graph.py
# dataset			exp_log		 graph	     training

# %% [markdown]
# ## 5. Install the conda environment defined in `environment.yml` (replacing the base environment):

# %%
# !mamba env update -n base -f environment.yml
# Out:
# pkgs/r/linux-64          [] (00m:00s)
# pkgs/r/linux-64          [] (00m:00s) 580 KB / ?? (1.88 MB/s)
# pkgs/r/linux-64          [] (00m:00s) 580 KB / ?? (1.88 MB/s)
# pkgs/main/linux-64       [] (00m:00s)
# pkgs/r/linux-64          [] (00m:00s) 580 KB / ?? (1.88 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/r/linux-64          [] (00m:00s) 580 KB / ?? (1.88 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s)
# pkgs/r/linux-64          [] (00m:00s) 580 KB / ?? (1.88 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s) 336 KB / ?? (1.08 MB/s)
# pkgs/r/linux-64          [] (00m:00s) 580 KB / ?? (1.88 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s) 336 KB / ?? (1.08 MB/s)
# pytorch/noarch           [] (--:--) Finalizing...
# pkgs/r/linux-64          [] (00m:00s) 580 KB / ?? (1.88 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s) 336 KB / ?? (1.08 MB/s)
# pytorch/noarch           [] (--:--) Done
# pkgs/r/linux-64          [] (00m:00s) 580 KB / ?? (1.88 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s) 336 KB / ?? (1.08 MB/s)
# pytorch/noarch           [] (00m:00s) Done
# pytorch/noarch           [] (00m:00s) Done
# pkgs/r/linux-64          [] (00m:00s) 580 KB / ?? (1.88 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s) 336 KB / ?? (1.08 MB/s)
# pkgs/r/linux-64          [] (00m:00s) Finalizing...
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s) 336 KB / ?? (1.08 MB/s)
# pkgs/r/linux-64          [] (00m:00s) Done
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s) 336 KB / ?? (1.08 MB/s)
# pkgs/r/linux-64          [] (00m:00s) Done
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s) 336 KB / ?? (1.08 MB/s)
# pkgs/r/linux-64          [] (00m:00s) Done
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s) 336 KB / ?? (1.08 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s) 336 KB / ?? (1.08 MB/s)
# pytorch/linux-64         [] (--:--) Finalizing...
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s) 336 KB / ?? (1.08 MB/s)
# pytorch/linux-64         [] (--:--) Done
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s) 336 KB / ?? (1.08 MB/s)
# pytorch/linux-64         [] (00m:00s) Done
# pytorch/linux-64         [] (00m:00s) Done
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s) 336 KB / ?? (1.08 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s) 336 KB / ?? (1.08 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s) 764 KB / ?? (1.64 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 612 KB / ?? (1.96 MB/s)
# pkgs/main/noarch         [] (00m:00s) 764 KB / ?? (1.64 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 1 MB / ?? (2.99 MB/s)
# pkgs/main/noarch         [] (00m:00s) 764 KB / ?? (1.64 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 1 MB / ?? (2.99 MB/s)
# pkgs/main/noarch         [] (00m:00s) Finalizing...
# pkgs/main/linux-64       [] (00m:00s) 1 MB / ?? (2.99 MB/s)
# pkgs/main/noarch         [] (00m:00s) Done
# pkgs/main/linux-64       [] (00m:00s) 1 MB / ?? (2.99 MB/s)
# pkgs/main/noarch         [] (00m:00s) Done
# pkgs/main/noarch         [] (00m:00s) Done
# pkgs/main/linux-64       [] (00m:00s) 1 MB / ?? (2.99 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 1 MB / ?? (2.99 MB/s)
# conda-forge/noarch       [] (00m:00s)
# pkgs/main/linux-64       [] (00m:00s) 1 MB / ?? (2.99 MB/s)
# conda-forge/noarch       [] (00m:00s) 548 KB / ?? (1.09 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 1 MB / ?? (2.99 MB/s)
# conda-forge/noarch       [] (00m:00s) 548 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s)
# pkgs/main/linux-64       [] (00m:00s) 1 MB / ?? (2.99 MB/s)
# conda-forge/noarch       [] (00m:00s) 548 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 268 KB / ?? (498.96 KB/s)
# pkgs/main/linux-64       [] (00m:00s) 1 MB / ?? (2.99 MB/s)
# conda-forge/noarch       [] (00m:00s) 548 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 268 KB / ?? (498.96 KB/s)
# pkgs/r/noarch            [] (00m:00s)
# pkgs/main/linux-64       [] (00m:00s) 1 MB / ?? (2.99 MB/s)
# conda-forge/noarch       [] (00m:00s) 548 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 268 KB / ?? (498.96 KB/s)
# pkgs/r/noarch            [] (00m:00s) 432 KB / ?? (720.02 KB/s)
# pkgs/main/linux-64       [] (00m:00s) 1 MB / ?? (2.99 MB/s)
# conda-forge/noarch       [] (00m:00s) 548 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 268 KB / ?? (498.96 KB/s)
# pkgs/r/noarch            [] (00m:00s) 432 KB / ?? (720.02 KB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (3.49 MB/s)
# conda-forge/noarch       [] (00m:00s) 548 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 268 KB / ?? (498.96 KB/s)
# pkgs/r/noarch            [] (00m:00s) 432 KB / ?? (720.02 KB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (3.49 MB/s)
# conda-forge/noarch       [] (00m:00s) 548 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 268 KB / ?? (498.96 KB/s)
# pkgs/r/noarch            [] (00m:00s) Finalizing...
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (3.49 MB/s)
# conda-forge/noarch       [] (00m:00s) 548 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 268 KB / ?? (498.96 KB/s)
# pkgs/r/noarch            [] (00m:00s) Done
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (3.49 MB/s)
# conda-forge/noarch       [] (00m:00s) 548 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 268 KB / ?? (498.96 KB/s)
# pkgs/r/noarch            [] (00m:00s) Done
# pkgs/r/noarch            [] (00m:00s) Done
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (3.49 MB/s)
# conda-forge/noarch       [] (00m:00s) 548 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 268 KB / ?? (498.96 KB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (3.49 MB/s)
# conda-forge/noarch       [] (00m:00s) 548 KB / ?? (1.09 MB/s)
# conda-forge/linux-64     [] (00m:00s) 268 KB / ?? (498.96 KB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (3.49 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (2.08 MB/s)
# conda-forge/linux-64     [] (00m:00s) 268 KB / ?? (498.96 KB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (3.49 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (2.08 MB/s)
# conda-forge/linux-64     [] (00m:00s) 268 KB / ?? (498.96 KB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (3.49 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (2.08 MB/s)
# conda-forge/linux-64     [] (00m:00s) 1 MB / ?? (1.62 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 2 MB / ?? (3.49 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (2.08 MB/s)
# conda-forge/linux-64     [] (00m:00s) 1 MB / ?? (1.62 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 3 MB / ?? (3.79 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (2.08 MB/s)
# conda-forge/linux-64     [] (00m:00s) 1 MB / ?? (1.62 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 3 MB / ?? (3.79 MB/s)
# conda-forge/noarch       [] (00m:00s) 1 MB / ?? (2.08 MB/s)
# conda-forge/linux-64     [] (00m:00s) 1 MB / ?? (1.62 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 3 MB / ?? (3.79 MB/s)
# conda-forge/noarch       [] (00m:00s) 2 MB / ?? (2.54 MB/s)
# conda-forge/linux-64     [] (00m:00s) 1 MB / ?? (1.62 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 3 MB / ?? (3.79 MB/s)
# conda-forge/noarch       [] (00m:00s) 2 MB / ?? (2.54 MB/s)
# conda-forge/linux-64     [] (00m:00s) 1 MB / ?? (1.62 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 3 MB / ?? (3.79 MB/s)
# conda-forge/noarch       [] (00m:00s) 2 MB / ?? (2.54 MB/s)
# conda-forge/linux-64     [] (00m:00s) 2 MB / ?? (2.30 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 3 MB / ?? (3.79 MB/s)
# conda-forge/noarch       [] (00m:00s) 2 MB / ?? (2.54 MB/s)
# conda-forge/linux-64     [] (00m:00s) 2 MB / ?? (2.30 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 4 MB / ?? (4.05 MB/s)
# conda-forge/noarch       [] (00m:00s) 2 MB / ?? (2.54 MB/s)
# conda-forge/linux-64     [] (00m:00s) 2 MB / ?? (2.30 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 4 MB / ?? (4.05 MB/s)
# conda-forge/noarch       [] (00m:00s) 2 MB / ?? (2.54 MB/s)
# conda-forge/linux-64     [] (00m:00s) 2 MB / ?? (2.30 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 4 MB / ?? (4.05 MB/s)
# conda-forge/noarch       [] (00m:00s) 3 MB / ?? (2.97 MB/s)
# conda-forge/linux-64     [] (00m:00s) 2 MB / ?? (2.30 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 4 MB / ?? (4.05 MB/s)
# conda-forge/noarch       [] (00m:00s) 3 MB / ?? (2.97 MB/s)
# conda-forge/linux-64     [] (00m:00s) 2 MB / ?? (2.30 MB/s)
# pkgs/main/linux-64       [] (00m:00s) 4 MB / ?? (4.05 MB/s)
# conda-forge/noarch       [] (00m:00s) 3 MB / ?? (2.97 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (2.77 MB/s)
# pkgs/main/linux-64       [] (00m:00s) Finalizing...
# conda-forge/noarch       [] (00m:00s) 3 MB / ?? (2.97 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (2.77 MB/s)
# pkgs/main/linux-64       [] (00m:00s) Done
# conda-forge/noarch       [] (00m:00s) 3 MB / ?? (2.97 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (2.77 MB/s)
# pkgs/main/linux-64       [] (00m:00s) Done
# conda-forge/noarch       [] (00m:00s) 3 MB / ?? (2.97 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (2.77 MB/s)
# pkgs/main/linux-64       [] (00m:00s) Done
# conda-forge/noarch       [] (00m:00s) 3 MB / ?? (2.97 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (2.77 MB/s)
# conda-forge/noarch       [] (00m:00s) 3 MB / ?? (2.97 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (2.77 MB/s)
# conda-forge/noarch       [] (00m:00s) 3 MB / ?? (2.76 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (2.77 MB/s)
# conda-forge/noarch       [] (00m:00s) 3 MB / ?? (2.76 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (2.77 MB/s)
# conda-forge/noarch       [] (00m:00s) 3 MB / ?? (2.76 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (2.65 MB/s)
# conda-forge/noarch       [] (00m:00s) 3 MB / ?? (2.76 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (2.65 MB/s)
# conda-forge/noarch       [] (00m:00s) 4 MB / ?? (3.45 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (2.65 MB/s)
# conda-forge/noarch       [] (00m:00s) 4 MB / ?? (3.45 MB/s)
# conda-forge/linux-64     [] (00m:00s) 3 MB / ?? (2.65 MB/s)
# conda-forge/noarch       [] (00m:00s) 4 MB / ?? (3.45 MB/s)
# conda-forge/linux-64     [] (00m:00s) 4 MB / ?? (3.28 MB/s)
# conda-forge/noarch       [] (00m:00s) 4 MB / ?? (3.45 MB/s)
# conda-forge/linux-64     [] (00m:00s) 4 MB / ?? (3.28 MB/s)
# conda-forge/noarch       [] (00m:00s) 5 MB / ?? (3.59 MB/s)
# conda-forge/linux-64     [] (00m:00s) 4 MB / ?? (3.28 MB/s)
# conda-forge/noarch       [] (00m:00s) 5 MB / ?? (3.59 MB/s)
# conda-forge/linux-64     [] (00m:00s) 4 MB / ?? (3.28 MB/s)
# conda-forge/noarch       [] (00m:00s) 5 MB / ?? (3.59 MB/s)
# conda-forge/linux-64     [] (00m:00s) 5 MB / ?? (3.50 MB/s)
# conda-forge/noarch       [] (00m:01s) 5 MB / ?? (3.59 MB/s)
# conda-forge/linux-64     [] (00m:01s) 5 MB / ?? (3.50 MB/s)
# conda-forge/noarch       [] (00m:01s) 6 MB / ?? (3.75 MB/s)
# conda-forge/linux-64     [] (00m:01s) 5 MB / ?? (3.50 MB/s)
# conda-forge/noarch       [] (00m:01s) 6 MB / ?? (3.75 MB/s)
# conda-forge/linux-64     [] (00m:01s) 5 MB / ?? (3.50 MB/s)
# conda-forge/noarch       [] (00m:01s) 6 MB / ?? (3.75 MB/s)
# conda-forge/linux-64     [] (00m:01s) 6 MB / ?? (3.67 MB/s)
# conda-forge/noarch       [] (00m:01s) 6 MB / ?? (3.75 MB/s)
# conda-forge/linux-64     [] (00m:01s) 6 MB / ?? (3.67 MB/s)
# conda-forge/noarch       [] (00m:01s) 7 MB / ?? (3.85 MB/s)
# conda-forge/linux-64     [] (00m:01s) 6 MB / ?? (3.67 MB/s)
# conda-forge/noarch       [] (00m:01s) 7 MB / ?? (3.85 MB/s)
# conda-forge/linux-64     [] (00m:01s) 6 MB / ?? (3.67 MB/s)
# conda-forge/noarch       [] (00m:01s) 7 MB / ?? (3.85 MB/s)
# conda-forge/linux-64     [] (00m:01s) 7 MB / ?? (3.78 MB/s)
# conda-forge/noarch       [] (00m:01s) Finalizing...
# conda-forge/linux-64     [] (00m:01s) 7 MB / ?? (3.78 MB/s)
# conda-forge/noarch       [] (00m:01s) Done
# conda-forge/linux-64     [] (00m:01s) 7 MB / ?? (3.78 MB/s)
# conda-forge/noarch       [] (00m:01s) Done
# conda-forge/linux-64     [] (00m:01s) 7 MB / ?? (3.78 MB/s)
# conda-forge/noarch       [] (00m:01s) Done
# conda-forge/linux-64     [] (00m:01s) 7 MB / ?? (3.78 MB/s)
# conda-forge/linux-64     [] (00m:01s) 7 MB / ?? (3.78 MB/s)
# conda-forge/linux-64     [] (00m:01s) 7 MB / ?? (3.46 MB/s)
# conda-forge/linux-64     [] (00m:01s) 7 MB / ?? (3.46 MB/s)
# conda-forge/linux-64     [] (00m:01s) 8 MB / ?? (4.02 MB/s)
# conda-forge/linux-64     [] (00m:01s) 8 MB / ?? (4.02 MB/s)
# conda-forge/linux-64     [] (00m:01s) 9 MB / ?? (4.11 MB/s)
# conda-forge/linux-64     [] (00m:01s) 9 MB / ?? (4.11 MB/s)
# conda-forge/linux-64     [] (00m:01s) 10 MB / ?? (4.18 MB/s)
# conda-forge/linux-64     [] (00m:02s) 10 MB / ?? (4.18 MB/s)
# conda-forge/linux-64     [] (00m:02s) 11 MB / ?? (4.24 MB/s)
# conda-forge/linux-64     [] (00m:02s) 11 MB / ?? (4.24 MB/s)
# conda-forge/linux-64     [] (00m:02s) 12 MB / ?? (4.31 MB/s)
# conda-forge/linux-64     [] (00m:02s) 12 MB / ?? (4.31 MB/s)
# conda-forge/linux-64     [] (00m:02s) 12 MB / ?? (4.36 MB/s)
# conda-forge/linux-64     [] (00m:02s) 12 MB / ?? (4.36 MB/s)
# conda-forge/linux-64     [] (00m:02s) 13 MB / ?? (4.40 MB/s)
# conda-forge/linux-64     [] (00m:02s) 13 MB / ?? (4.40 MB/s)
# conda-forge/linux-64     [] (00m:02s) 14 MB / ?? (4.44 MB/s)
# conda-forge/linux-64     [] (00m:02s) 14 MB / ?? (4.44 MB/s)
# conda-forge/linux-64     [] (00m:02s) 15 MB / ?? (4.46 MB/s)
# conda-forge/linux-64     [] (00m:02s) 15 MB / ?? (4.46 MB/s)
# conda-forge/linux-64     [] (00m:02s) 15 MB / ?? (4.48 MB/s)
# conda-forge/linux-64     [] (00m:03s) 15 MB / ?? (4.48 MB/s)
# conda-forge/linux-64     [] (00m:03s) 16 MB / ?? (4.50 MB/s)
# conda-forge/linux-64     [] (00m:03s) 16 MB / ?? (4.50 MB/s)
# conda-forge/linux-64     [] (00m:03s) 17 MB / ?? (4.49 MB/s)
# conda-forge/linux-64     [] (00m:03s) 17 MB / ?? (4.49 MB/s)
# conda-forge/linux-64     [] (00m:03s) 18 MB / ?? (4.52 MB/s)
# conda-forge/linux-64     [] (00m:03s) 18 MB / ?? (4.52 MB/s)
# conda-forge/linux-64     [] (00m:03s) 18 MB / ?? (4.55 MB/s)
# conda-forge/linux-64     [] (00m:03s) 18 MB / ?? (4.55 MB/s)
# conda-forge/linux-64     [] (00m:03s) 19 MB / ?? (4.59 MB/s)
# conda-forge/linux-64     [] (00m:03s) Finalizing...
# conda-forge/linux-64     [] (00m:04s) Done
# conda-forge/linux-64     [] (00m:04s) Done
# conda-forge/linux-64     [] (00m:04s) Done
#
#
# Looking for: ['_libgcc_mutex==0.1=main', 'alabaster==0.7.12=py37_0', 'anaconda==2020.07=py37_0', 'anaconda-client==1.7.2=py37_0', 'anaconda-project==0.8.4=py_0', 'argh==0.26.2=py37_0', 'asn1crypto==1.3.0=py37_1', 'astroid==2.4.2=py37_0', 'astropy==4.0.1.post1=py37h7b6447c_1', 'atomicwrites==1.4.0=py_0', 'attrs==19.3.0=py_0', 'autopep8==1.5.3=py_0', 'babel==2.8.0=py_0', 'backcall==0.2.0=py_0', 'backports==1.0=py_2', 'backports.shutil_get_terminal_size==1.0.0=py37_2', 'beautifulsoup4==4.9.1=py37_0', 'bitarray==1.4.0=py37h7b6447c_0', 'bkcharts==0.2=py37_0', 'blas==1.0=mkl', 'bleach==3.1.5=py_0', 'blosc==1.19.0=hd408876_0', 'bokeh==2.1.1=py37_0', 'boto==2.49.0=py37_0', 'bottleneck==1.3.2=py37heb32a55_1', 'brotlipy==0.7.0=py37h7b6447c_1000', 'bzip2==1.0.8=h7b6447c_0', 'ca-certificates==2020.6.24=0', 'cairo==1.14.12=h8948797_3', 'certifi==2020.6.20=py37_0', 'cffi==1.14.0=py37he30daa8_1', 'chardet==3.0.4=py37_1003', 'click==7.1.2=py_0', 'cloudpickle==1.5.0=py_0', 'clyent==1.2.2=py37_1', 'colorama==0.4.3=py_0', 'contextlib2==0.6.0.post1=py_0', 'cryptography==2.9.2=py37h1ba5d50_0', 'cudatoolkit==10.2.89=hfd86e86_1', 'curl==7.71.1=hbc83047_1', 'cycler==0.10.0=py37_0', 'cython==0.29.21=py37he6710b0_0', 'cytoolz==0.10.1=py37h7b6447c_0', 'dask==2.20.0=py_0', 'dask-core==2.20.0=py_0', 'dbus==1.13.16=hb2f20db_0', 'decorator==4.4.2=py_0', 'defusedxml==0.6.0=py_0', 'diff-match-patch==20200713=py_0', 'distributed==2.20.0=py37_0', 'docutils==0.16=py37_1', 'entrypoints==0.3=py37_0', 'et_xmlfile==1.0.1=py_1001', 'expat==2.2.9=he6710b0_2', 'fastcache==1.1.0=py37h7b6447c_0', 'filelock==3.0.12=py_0', 'flake8==3.8.3=py_0', 'flask==1.1.2=py_0', 'fontconfig==2.13.0=h9420a91_0', 'freetype==2.10.2=h5ab3b9f_0', 'fribidi==1.0.9=h7b6447c_0', 'fsspec==0.7.4=py_0', 'future==0.18.2=py37_1', 'get_terminal_size==1.0.0=haa9412d_0', 'gevent==20.6.2=py37h7b6447c_0', 'glib==2.65.0=h3eb4bd4_0', 'glob2==0.7=py_0', 'gmp==6.1.2=h6c8ec71_1', 'gmpy2==2.0.8=py37h10f8cd9_2', 'graphite2==1.3.14=h23475e2_0', 'greenlet==0.4.16=py37h7b6447c_0', 'gst-plugins-base==1.14.0=hbbd80ab_1', 'gstreamer==1.14.0=hb31296c_0', 'h5py==2.10.0=py37h7918eee_0', 'harfbuzz==2.4.0=hca77d97_1', 'hdf5==1.10.4=hb1b8bf9_0', 'heapdict==1.0.1=py_0', 'html5lib==1.1=py_0', 'icu==58.2=he6710b0_3', 'idna==2.10=py_0', 'imageio==2.9.0=py_0', 'imagesize==1.2.0=py_0', 'importlib-metadata==1.7.0=py37_0', 'importlib_metadata==1.7.0=0', 'intel-openmp==2020.1=217', 'intervaltree==3.0.2=py_1', 'ipykernel==5.3.2=py37h5ca1d4c_0', 'ipython==7.16.1=py37h5ca1d4c_0', 'ipython_genutils==0.2.0=py37_0', 'ipywidgets==7.5.1=py_0', 'isort==4.3.21=py37_0', 'itsdangerous==1.1.0=py37_0', 'jbig==2.1=hdba287a_0', 'jdcal==1.4.1=py_0', 'jedi==0.17.1=py37_0', 'jeepney==0.4.3=py_0', 'jinja2==2.11.2=py_0', 'joblib==0.16.0=py_0', 'jpeg==9b=h024ee3a_2', 'json5==0.9.5=py_0', 'jsonschema==3.2.0=py37_1', 'jupyter==1.0.0=py37_7', 'jupyter_client==6.1.6=py_0', 'jupyter_console==6.1.0=py_0', 'jupyter_core==4.6.3=py37_0', 'jupyterlab==2.1.5=py_0', 'jupyterlab_server==1.2.0=py_0', 'keyring==21.2.1=py37_0', 'kiwisolver==1.2.0=py37hfd86e86_0', 'krb5==1.18.2=h173b8e3_0', 'lazy-object-proxy==1.4.3=py37h7b6447c_0', 'lcms2==2.11=h396b838_0', 'ld_impl_linux-64==2.33.1=h53a641e_7', 'libarchive==3.4.2=h62408e4_0', 'libcurl==7.71.1=h20c2e04_1', 'libedit==3.1.20191231=h14c3975_1', 'libffi==3.3=he6710b0_2', 'libgcc-ng==9.1.0=hdf63c60_0', 'libgfortran-ng==7.3.0=hdf63c60_0', 'liblief==0.10.1=he6710b0_0', 'libllvm9==9.0.1=h4a3c616_1', 'libpng==1.6.37=hbc83047_0', 'libsodium==1.0.18=h7b6447c_0', 'libspatialindex==1.9.3=he6710b0_0', 'libssh2==1.9.0=h1ba5d50_1', 'libstdcxx-ng==9.1.0=hdf63c60_0', 'libtiff==4.1.0=h2733197_1', 'libtool==2.4.6=h7b6447c_5', 'libuuid==1.0.3=h1bed415_2', 'libxcb==1.14=h7b6447c_0', 'libxml2==2.9.10=he19cac6_1', 'libxslt==1.1.34=hc22bd24_0', 'llvmlite==0.33.0=py37hc6ec683_1', 'locket==0.2.0=py37_1', 'lxml==4.5.2=py37hefd8a0e_0', 'lz4-c==1.9.2=he6710b0_0', 'lzo==2.10=h7b6447c_2', 'markupsafe==1.1.1=py37h14c3975_1', 'matplotlib==3.2.2=0', 'mat ...
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - _libgcc_mutex==0.1=main
#    - alabaster==0.7.12=py37_0
#    - anaconda==2020.07=py37_0
#    - anaconda-client==1.7.2=py37_0
#    - anaconda-project==0.8.4=py_0
#    - argh==0.26.2=py37_0
#    - asn1crypto==1.3.0=py37_1
#    - astroid==2.4.2=py37_0
#    - astropy==4.0.1.post1=py37h7b6447c_1
#    - atomicwrites==1.4.0=py_0
#    - attrs==19.3.0=py_0
#    - autopep8==1.5.3=py_0
#    - babel==2.8.0=py_0
#    - backcall==0.2.0=py_0
#    - backports==1.0=py_2
#    - backports.shutil_get_terminal_size==1.0.0=py37_2
#    - beautifulsoup4==4.9.1=py37_0
#    - bitarray==1.4.0=py37h7b6447c_0
#    - bkcharts==0.2=py37_0
#    - blas==1.0=mkl
#    - bleach==3.1.5=py_0
#    - blosc==1.19.0=hd408876_0
#    - bokeh==2.1.1=py37_0
#    - boto==2.49.0=py37_0
#    - bottleneck==1.3.2=py37heb32a55_1
#    - brotlipy==0.7.0=py37h7b6447c_1000
#    - bzip2==1.0.8=h7b6447c_0
#    - ca-certificates==2020.6.24=0
#    - cairo==1.14.12=h8948797_3
#    - certifi==2020.6.20=py37_0
#    - cffi==1.14.0=py37he30daa8_1
#    - chardet==3.0.4=py37_1003
#    - click==7.1.2=py_0
#    - cloudpickle==1.5.0=py_0
#    - clyent==1.2.2=py37_1
#    - colorama==0.4.3=py_0
#    - contextlib2==0.6.0.post1=py_0
#    - cryptography==2.9.2=py37h1ba5d50_0
#    - cudatoolkit==10.2.89=hfd86e86_1
#    - curl==7.71.1=hbc83047_1
#    - cycler==0.10.0=py37_0
#    - cython==0.29.21=py37he6710b0_0
#    - cytoolz==0.10.1=py37h7b6447c_0
#    - dask==2.20.0=py_0
#    - dask-core==2.20.0=py_0
#    - dbus==1.13.16=hb2f20db_0
#    - decorator==4.4.2=py_0
#    - defusedxml==0.6.0=py_0
#    - diff-match-patch==20200713=py_0
#    - distributed==2.20.0=py37_0
#    - docutils==0.16=py37_1
#    - entrypoints==0.3=py37_0
#    - et_xmlfile==1.0.1=py_1001
#    - expat==2.2.9=he6710b0_2
#    - fastcache==1.1.0=py37h7b6447c_0
#    - filelock==3.0.12=py_0
#    - flake8==3.8.3=py_0
#    - flask==1.1.2=py_0
#    - fontconfig==2.13.0=h9420a91_0
#    - freetype==2.10.2=h5ab3b9f_0
#    - fribidi==1.0.9=h7b6447c_0
#    - fsspec==0.7.4=py_0
#    - future==0.18.2=py37_1
#    - get_terminal_size==1.0.0=haa9412d_0
#    - gevent==20.6.2=py37h7b6447c_0
#    - glib==2.65.0=h3eb4bd4_0
#    - glob2==0.7=py_0
#    - gmp==6.1.2=h6c8ec71_1
#    - gmpy2==2.0.8=py37h10f8cd9_2
#    - graphite2==1.3.14=h23475e2_0
#    - greenlet==0.4.16=py37h7b6447c_0
#    - gst-plugins-base==1.14.0=hbbd80ab_1
#    - gstreamer==1.14.0=hb31296c_0
#    - h5py==2.10.0=py37h7918eee_0
#    - harfbuzz==2.4.0=hca77d97_1
#    - hdf5==1.10.4=hb1b8bf9_0
#    - heapdict==1.0.1=py_0
#    - html5lib==1.1=py_0
#    - icu==58.2=he6710b0_3
#    - idna==2.10=py_0
#    - imageio==2.9.0=py_0
#    - imagesize==1.2.0=py_0
#    - importlib-metadata==1.7.0=py37_0
#    - importlib_metadata==1.7.0=0
#    - intel-openmp==2020.1=217
#    - intervaltree==3.0.2=py_1
#    - ipykernel==5.3.2=py37h5ca1d4c_0
#    - ipython==7.16.1=py37h5ca1d4c_0
#    - ipython_genutils==0.2.0=py37_0
#    - ipywidgets==7.5.1=py_0
#    - isort==4.3.21=py37_0
#    - itsdangerous==1.1.0=py37_0
#    - jbig==2.1=hdba287a_0
#    - jdcal==1.4.1=py_0
#    - jedi==0.17.1=py37_0
#    - jeepney==0.4.3=py_0
#    - jinja2==2.11.2=py_0
#    - joblib==0.16.0=py_0
#    - jpeg==9b=h024ee3a_2
#    - json5==0.9.5=py_0
#    - jsonschema==3.2.0=py37_1
#    - jupyter==1.0.0=py37_7
#    - jupyter_client==6.1.6=py_0
#    - jupyter_console==6.1.0=py_0
#    - jupyter_core==4.6.3=py37_0
#    - jupyterlab==2.1.5=py_0
#    - jupyterlab_server==1.2.0=py_0
#    - keyring==21.2.1=py37_0
#    - kiwisolver==1.2.0=py37hfd86e86_0
#    - krb5==1.18.2=h173b8e3_0
#    - lazy-object-proxy==1.4.3=py37h7b6447c_0
#    - lcms2==2.11=h396b838_0
#    - ld_impl_linux-64==2.33.1=h53a641e_7
#    - libarchive==3.4.2=h62408e4_0
#    - libcurl==7.71.1=h20c2e04_1
#    - libedit==3.1.20191231=h14c3975_1
#    - libffi==3.3=he6710b0_2
#    - libgcc-ng==9.1.0=hdf63c60_0
#    - libgfortran-ng==7.3.0=hdf63c60_0
#    - liblief==0.10.1=he6710b0_0
#    - libllvm9==9.0.1=h4a3c616_1
#    - libpng==1.6.37=hbc83047_0
#    - libsodium==1.0.18=h7b6447c_0
#    - libspatialindex==1.9.3=he6710b0_0
#    - libssh2==1.9.0=h1ba5d50_1
#    - libstdcxx-ng==9.1.0=hdf63c60_0
#    - libtiff==4.1.0=h2733197_1
#    - libtool==2.4.6=h7b6447c_5
#    - libuuid==1.0.3=h1bed415_2
#    - libxcb==1.14=h7b6447c_0
#    - libxml2==2.9.10=he19cac6_1
#    - libxslt==1.1.34=hc22bd24_0
#    - llvmlite==0.33.0=py37hc6ec683_1
#    - locket==0.2.0=py37_1
#    - lxml==4.5.2=py37hefd8a0e_0
#    - lz4-c==1.9.2=he6710b0_0
#    - lzo==2.10=h7b6447c_2
#    - markupsafe==1.1.1=py37h14c3975_1
#    - matplotlib==3.2.2=0
#    - matplotlib-base==3.2.2=py37hef1b27d_0
#    - mccabe==0.6.1=py37_1
#    - mistune==0.8.4=py37h14c3975_1001
#    - mkl==2020.1=217
#    - mkl-service==2.3.0=py37he904b0f_0
#    - mkl_fft==1.1.0=py37h23d657b_0
#    - mkl_random==1.1.1=py37h0573a6f_0
#    - mock==4.0.2=py_0
#    - more-itertools==8.4.0=py_0
#    - mpc==1.1.0=h10f8cd9_1
#    - mpfr==4.0.2=hb69a4c5_1
#    - mpmath==1.1.0=py37_0
#    - msgpack-python==1.0.0=py37hfd86e86_1
#    - multipledispatch==0.6.0=py37_0
#    - nbconvert==5.6.1=py37_1
#    - nbformat==5.0.7=py_0
#    - ncurses==6.2=he6710b0_1
#    - networkx==2.4=py_1
#    - ninja==1.10.0=py37hfd86e86_0
#    - nltk==3.5=py_0
#    - nose==1.3.7=py37_1004
#    - notebook==6.0.3=py37_0
#    - numba==0.50.1=py37h0573a6f_1
#    - numexpr==2.7.1=py37h423224d_0
#    - numpy==1.18.5=py37ha1c710e_0
#    - numpy-base==1.18.5=py37hde5b4d6_0
#    - numpydoc==1.1.0=py_0
#    - olefile==0.46=py37_0
#    - openpyxl==3.0.4=py_0
#    - openssl==1.1.1g=h7b6447c_0
#    - packaging==20.4=py_0
#    - pandas==1.0.5=py37h0573a6f_0
#    - pandoc==2.10=0
#    - pandocfilters==1.4.2=py37_1
#    - pango==1.45.3=hd140c19_0
#    - parso==0.7.0=py_0
#    - partd==1.1.0=py_0
#    - patchelf==0.11=he6710b0_0
#    - path==13.1.0=py37_0
#    - path.py==12.4.0=0
#    - pathlib2==2.3.5=py37_1
#    - pathtools==0.1.2=py_1
#    - patsy==0.5.1=py37_0
#    - pcre==8.44=he6710b0_0
#    - pep8==1.7.1=py37_0
#    - pexpect==4.8.0=py37_1
#    - pickleshare==0.7.5=py37_1001
#    - pillow==7.2.0=py37hb39fc2d_0
#    - pip==20.1.1=py37_1
#    - pixman==0.40.0=h7b6447c_0
#    - pkginfo==1.5.0.1=py37_0
#    - pluggy==0.13.1=py37_0
#    - ply==3.11=py37_0
#    - prometheus_client==0.8.0=py_0
#    - prompt-toolkit==3.0.5=py_0
#    - prompt_toolkit==3.0.5=0
#    - psutil==5.7.0=py37h7b6447c_0
#    - ptyprocess==0.6.0=py37_0
#    - py==1.9.0=py_0
#    - py-lief==0.10.1=py37h403a769_0
#    - pycodestyle==2.6.0=py_0
#    - pycosat==0.6.3=py37h7b6447c_0
#    - pycparser==2.20=py_2
#    - pycrypto==2.6.1=py37h7b6447c_10
#    - pycurl==7.43.0.5=py37h1ba5d50_0
#    - pydocstyle==5.0.2=py_0
#    - pyflakes==2.2.0=py_0
#    - pygments==2.6.1=py_0
#    - pylint==2.5.3=py37_0
#    - pyodbc==4.0.30=py37he6710b0_0
#    - pyopenssl==19.1.0=py_1
#    - pyparsing==2.4.7=py_0
#    - pyqt==5.9.2=py37h05f1152_2
#    - pyrsistent==0.16.0=py37h7b6447c_0
#    - pysocks==1.7.1=py37_1
#    - pytables==3.6.1=py37h71ec239_0
#    - pytest==5.4.3=py37_0
#    - python==3.7.7=hcff3b4d_5
#    - python-dateutil==2.8.1=py_0
#    - python-jsonrpc-server==0.3.4=py_1
#    - python-language-server==0.34.1=py37_0
#    - python-libarchive-c==2.9=py_0
#    - pytorch==1.5.1=py3.7_cuda10.2.89_cudnn7.6.5_0
#    - pytz==2020.1=py_0
#    - pywavelets==1.1.1=py37h7b6447c_0
#    - pyxdg==0.26=py_0
#    - pyyaml==5.3.1=py37h7b6447c_1
#    - pyzmq==19.0.1=py37he6710b0_1
#    - qdarkstyle==2.8.1=py_0
#    - qt==5.9.7=h5867ecd_1
#    - qtawesome==0.7.2=py_0
#    - qtconsole==4.7.5=py_0
#    - qtpy==1.9.0=py_0
#    - readline==8.0=h7b6447c_0
#    - regex==2020.6.8=py37h7b6447c_0
#    - requests==2.24.0=py_0
#    - ripgrep==11.0.2=he32d670_0
#    - rope==0.17.0=py_0
#    - rtree==0.9.4=py37_1
#    - ruamel_yaml==0.15.87=py37h7b6447c_1
#    - scikit-image==0.16.2=py37h0573a6f_0
#    - scikit-learn==0.23.1=py37h423224d_0
#    - scipy==1.5.0=py37h0b6359f_0
#    - seaborn==0.10.1=py_0
#    - secretstorage==3.1.2=py37_1
#    - send2trash==1.5.0=py37_0
#    - setuptools==49.2.0=py37_0
#    - simplegeneric==0.8.1=py37_2
#    - singledispatch==3.4.0.3=py37_0
#    - sip==4.19.8=py37hf484d3e_0
#    - six==1.15.0=py_0
#    - snappy==1.1.8=he6710b0_0
#    - snowballstemmer==2.0.0=py_0
#    - sortedcollections==1.2.1=py_0
#    - sortedcontainers==2.2.2=py_0
#    - soupsieve==2.0.1=py_0
#    - sphinx==3.1.2=py_0
#    - sphinxcontrib==1.0=py37_1
#    - sphinxcontrib-applehelp==1.0.2=py_0
#    - sphinxcontrib-devhelp==1.0.2=py_0
#    - sphinxcontrib-htmlhelp==1.0.3=py_0
#    - sphinxcontrib-jsmath==1.0.1=py_0
#    - sphinxcontrib-qthelp==1.0.3=py_0
#    - sphinxcontrib-serializinghtml==1.1.4=py_0
#    - sphinxcontrib-websupport==1.2.3=py_0
#    - spyder==4.1.4=py37_0
#    - spyder-kernels==1.9.2=py37_0
#    - sqlalchemy==1.3.18=py37h7b6447c_0
#    - sqlite==3.32.3=h62c20be_0
#    - statsmodels==0.11.1=py37h7b6447c_0
#    - sympy==1.6.1=py37_0
#    - tbb==2020.0=hfd86e86_0
#    - tblib==1.6.0=py_0
#    - terminado==0.8.3=py37_0
#    - testpath==0.4.4=py_0
#    - threadpoolctl==2.1.0=pyh5ca1d4c_0
#    - tk==8.6.10=hbc83047_0
#    - toml==0.10.1=py_0
#    - toolz==0.10.0=py_0
#    - torchvision==0.6.1=py37_cu102
#    - tornado==6.0.4=py37h7b6447c_1
#    - tqdm==4.47.0=py_0
#    - traitlets==4.3.3=py37_0
#    - typed-ast==1.4.1=py37h7b6447c_0
#    - typing_extensions==3.7.4.2=py_0
#    - ujson==1.35=py37h14c3975_0
#    - unicodecsv==0.14.1=py37_0
#    - unixodbc==2.3.7=h14c3975_0
#    - urllib3==1.25.9=py_0
#    - watchdog==0.10.3=py37_0
#    - wcwidth==0.2.5=py_0
#    - webencodings==0.5.1=py37_1
#    - werkzeug==1.0.1=py_0
#    - wheel==0.34.2=py37_0
#    - widgetsnbextension==3.5.1=py37_0
#    - wrapt==1.11.2=py37h7b6447c_0
#    - wurlitzer==2.0.1=py37_0
#    - xlrd==1.2.0=py37_0
#    - xlsxwriter==1.2.9=py_0
#    - xlwt==1.3.0=py37_0
#    - xz==5.2.5=h7b6447c_0
#    - yaml==0.2.5=h7b6447c_0
#    - yapf==0.30.0=py_0
#    - zeromq==4.3.2=he6710b0_2
#    - zict==2.0.0=py_0
#    - zipp==3.1.0=py_0
#    - zlib==1.2.11=h7b6447c_3
#    - zope==1.0=py37_1
#    - zope.event==4.4=py37_0
#    - zope.interface==4.7.1=py37h7b6447c_0
#    - zstd==1.4.5=h0b5b093_0
#
#
#   Package                                  Version  Build                           Channel                     Size
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   alabaster                                 0.7.12  py37_0                          pkgs/main/linux-64         18 KB
#   anaconda                                 2020.07  py37_0                          pkgs/main/linux-64         17 KB
#   anaconda-client                            1.7.2  py37_0                          pkgs/main/linux-64        147 KB
#   anaconda-project                           0.8.4  py_0                            pkgs/main/noarch          210 KB
#   argh                                      0.26.2  py37_0                          pkgs/main/linux-64         36 KB
#   asn1crypto                                 1.3.0  py37_1                          pkgs/main/linux-64        164 KB
#   astroid                                    2.4.2  py37_0                          pkgs/main/linux-64        279 KB
#   astropy                              4.0.1.post1  py37h7b6447c_1                  pkgs/main/linux-64          6 MB
#   atomicwrites                               1.4.0  py_0                            pkgs/main/noarch           11 KB
#   attrs                                     19.3.0  py_0                            pkgs/main/noarch           40 KB
#   autopep8                                   1.5.3  py_0                            pkgs/main/noarch           45 KB
#   babel                                      2.8.0  py_0                            pkgs/main/noarch            5 MB
#   backcall                                   0.2.0  py_0                            pkgs/main/noarch           15 KB
#   backports                                    1.0  py_2                            pkgs/main/noarch          160 KB
#   backports.shutil_get_terminal_size         1.0.0  py37_2                          pkgs/main/linux-64          8 KB
#   beautifulsoup4                             4.9.1  py37_0                          pkgs/main/linux-64        165 KB
#   bitarray                                   1.4.0  py37h7b6447c_0                  pkgs/main/linux-64         88 KB
#   bkcharts                                     0.2  py37_0                          pkgs/main/linux-64        133 KB
#   blas                                         1.0  mkl                             pkgs/main/linux-64          6 KB
#   bleach                                     3.1.5  py_0                            pkgs/main/noarch          116 KB
#   blosc                                     1.19.0  hd408876_0                      pkgs/main/linux-64         71 KB
#   bokeh                                      2.1.1  py37_0                          pkgs/main/linux-64          5 MB
#   boto                                      2.49.0  py37_0                          pkgs/main/linux-64          1 MB
#   bottleneck                                 1.3.2  py37heb32a55_1                  pkgs/main/linux-64        125 KB
#   cairo                                    1.14.12  h8948797_3                      pkgs/main/linux-64        906 KB
#   click                                      7.1.2  py_0                            pkgs/main/noarch           71 KB
#   cloudpickle                                1.5.0  py_0                            pkgs/main/noarch           22 KB
#   clyent                                     1.2.2  py37_1                          pkgs/main/linux-64         19 KB
#   colorama                                   0.4.3  py_0                            pkgs/main/noarch           20 KB
#   contextlib2                          0.6.0.post1  py_0                            pkgs/main/noarch           16 KB
#   cudatoolkit                              10.2.89  hfd86e86_1                      pkgs/main/linux-64        365 MB
#   curl                                      7.71.1  hbc83047_1                      pkgs/main/linux-64        140 KB
#   cycler                                    0.10.0  py37_0                          pkgs/main/linux-64         13 KB
#   cython                                   0.29.21  py37he6710b0_0                  pkgs/main/linux-64          2 MB
#   cytoolz                                   0.10.1  py37h7b6447c_0                  pkgs/main/linux-64        376 KB
#   dask                                      2.20.0  py_0                            pkgs/main/noarch            4 KB
#   dask-core                                 2.20.0  py_0                            pkgs/main/noarch          590 KB
#   dbus                                     1.13.16  hb2f20db_0                      pkgs/main/linux-64        501 KB
#   decorator                                  4.4.2  py_0                            pkgs/main/noarch           14 KB
#   defusedxml                                 0.6.0  py_0                            pkgs/main/noarch           23 KB
#   diff-match-patch                        20200713  py_0                            pkgs/main/noarch           36 KB
#   distributed                               2.20.0  py37_0                          pkgs/main/linux-64        992 KB
#   docutils                                    0.16  py37_1                          pkgs/main/linux-64        660 KB
#   entrypoints                                  0.3  py37_0                          pkgs/main/linux-64         12 KB
#   et_xmlfile                                 1.0.1  py_1001                         pkgs/main/noarch           12 KB
#   expat                                      2.2.9  he6710b0_2                      pkgs/main/linux-64        156 KB
#   fastcache                                  1.1.0  py37h7b6447c_0                  pkgs/main/linux-64         30 KB
#   filelock                                  3.0.12  py_0                            pkgs/main/noarch           13 KB
#   flake8                                     3.8.3  py_0                            pkgs/main/noarch          134 KB
#   flask                                      1.1.2  py_0                            pkgs/main/noarch           78 KB
#   fontconfig                                2.13.0  h9420a91_0                      pkgs/main/linux-64        227 KB
#   freetype                                  2.10.2  h5ab3b9f_0                      pkgs/main/linux-64        608 KB
#   fribidi                                    1.0.9  h7b6447c_0                      pkgs/main/linux-64        104 KB
#   fsspec                                     0.7.4  py_0                            pkgs/main/noarch           63 KB
#   future                                    0.18.2  py37_1                          pkgs/main/linux-64        631 KB
#   get_terminal_size                          1.0.0  haa9412d_0                      pkgs/main/linux-64          3 KB
#   gevent                                    20.6.2  py37h7b6447c_0                  pkgs/main/linux-64          2 MB
#   glib                                      2.65.0  h3eb4bd4_0                      pkgs/main/linux-64          3 MB
#   glob2                                        0.7  py_0                            pkgs/main/noarch           15 KB
#   gmp                                        6.1.2  h6c8ec71_1                      pkgs/main/linux-64        514 KB
#   gmpy2                                      2.0.8  py37h10f8cd9_2                  pkgs/main/linux-64        150 KB
#   graphite2                                 1.3.14  h23475e2_0                      pkgs/main/linux-64         99 KB
#   greenlet                                  0.4.16  py37h7b6447c_0                  pkgs/main/linux-64         24 KB
#   gst-plugins-base                          1.14.0  hbbd80ab_1                      pkgs/main/linux-64          5 MB
#   gstreamer                                 1.14.0  hb31296c_0                      pkgs/main/linux-64          3 MB
#   h5py                                      2.10.0  py37h7918eee_0                  pkgs/main/linux-64          1 MB
#   harfbuzz                                   2.4.0  hca77d97_1                      pkgs/main/linux-64        850 KB
#   hdf5                                      1.10.4  hb1b8bf9_0                      pkgs/main/linux-64          4 MB
#   heapdict                                   1.0.1  py_0                            pkgs/main/noarch            9 KB
#   html5lib                                     1.1  py_0                            pkgs/main/noarch           93 KB
#   imageio                                    2.9.0  py_0                            pkgs/main/noarch            3 MB
#   imagesize                                  1.2.0  py_0                            pkgs/main/noarch           10 KB
#   importlib-metadata                         1.7.0  py37_0                          pkgs/main/linux-64         51 KB
#   importlib_metadata                         1.7.0  0                               pkgs/main/noarch           11 KB
#   intel-openmp                              2020.1  217                             pkgs/main/linux-64        780 KB
#   intervaltree                               3.0.2  py_1                            pkgs/main/noarch           24 KB
#   ipykernel                                  5.3.2  py37h5ca1d4c_0                  pkgs/main/linux-64        179 KB
#   ipython                                   7.16.1  py37h5ca1d4c_0                  pkgs/main/linux-64        987 KB
#   ipython_genutils                           0.2.0  py37_0                          pkgs/main/linux-64         39 KB
#   ipywidgets                                 7.5.1  py_0                            pkgs/main/noarch          104 KB
#   isort                                     4.3.21  py37_0                          pkgs/main/linux-64         69 KB
#   itsdangerous                               1.1.0  py37_0                          pkgs/main/linux-64         28 KB
#   jbig                                         2.1  hdba287a_0                      pkgs/main/linux-64         40 KB
#   jdcal                                      1.4.1  py_0                            pkgs/main/noarch           11 KB
#   jedi                                      0.17.1  py37_0                          pkgs/main/linux-64        921 KB
#   jeepney                                    0.4.3  py_0                            pkgs/main/noarch           21 KB
#   jinja2                                    2.11.2  py_0                            pkgs/main/noarch          103 KB
#   joblib                                    0.16.0  py_0                            pkgs/main/noarch          210 KB
#   jpeg                                          9b  h024ee3a_2                      pkgs/main/linux-64        214 KB
#   json5                                      0.9.5  py_0                            pkgs/main/noarch           22 KB
#   jsonschema                                 3.2.0  py37_1                          pkgs/main/linux-64         91 KB
#   jupyter                                    1.0.0  py37_7                          pkgs/main/linux-64          6 KB
#   jupyter_client                             6.1.6  py_0                            pkgs/main/noarch           84 KB
#   jupyter_console                            6.1.0  py_0                            pkgs/main/noarch           24 KB
#   jupyter_core                               4.6.3  py37_0                          pkgs/main/linux-64         71 KB
#   jupyterlab                                 2.1.5  py_0                            pkgs/main/noarch            3 MB
#   jupyterlab_server                          1.2.0  py_0                            pkgs/main/noarch           25 KB
#   keyring                                   21.2.1  py37_0                          pkgs/main/linux-64         58 KB
#   kiwisolver                                 1.2.0  py37hfd86e86_0                  pkgs/main/linux-64         84 KB
#   lazy-object-proxy                          1.4.3  py37h7b6447c_0                  pkgs/main/linux-64         29 KB
#   lcms2                                       2.11  h396b838_0                      pkgs/main/linux-64        307 KB
#   libgfortran-ng                             7.3.0  hdf63c60_0                      pkgs/main/linux-64       1006 KB
#   liblief                                   0.10.1  he6710b0_0                      pkgs/main/linux-64          2 MB
#   libllvm9                                   9.0.1  h4a3c616_1                      pkgs/main/linux-64         21 MB
#   libpng                                    1.6.37  hbc83047_0                      pkgs/main/linux-64        278 KB
#   libsodium                                 1.0.18  h7b6447c_0                      pkgs/main/linux-64        244 KB
#   libspatialindex                            1.9.3  he6710b0_0                      pkgs/main/linux-64          2 MB
#   libtiff                                    4.1.0  h2733197_1                      pkgs/main/linux-64        449 KB
#   libtool                                    2.4.6  h7b6447c_5                      pkgs/main/linux-64        389 KB
#   libuuid                                    1.0.3  h1bed415_2                      pkgs/main/linux-64         15 KB
#   libxcb                                      1.14  h7b6447c_0                      pkgs/main/linux-64        505 KB
#   libxslt                                   1.1.34  hc22bd24_0                      pkgs/main/linux-64        432 KB
#   llvmlite                                  0.33.0  py37hc6ec683_1                  pkgs/main/linux-64         17 MB
#   locket                                     0.2.0  py37_1                          pkgs/main/linux-64          9 KB
#   lxml                                       4.5.2  py37hefd8a0e_0                  pkgs/main/linux-64          1 MB
#   markupsafe                                 1.1.1  py37h14c3975_1                  pkgs/main/linux-64         26 KB
#   matplotlib                                 3.2.2  0                               pkgs/main/linux-64         21 KB
#   matplotlib-base                            3.2.2  py37hef1b27d_0                  pkgs/main/linux-64          5 MB
#   mccabe                                     0.6.1  py37_1                          pkgs/main/linux-64         14 KB
#   mistune                                    0.8.4  py37h14c3975_1001               pkgs/main/linux-64         54 KB
#   mkl                                       2020.1  217                             pkgs/main/linux-64        129 MB
#   mkl-service                                2.3.0  py37he904b0f_0                  pkgs/main/linux-64        218 KB
#   mkl_fft                                    1.1.0  py37h23d657b_0                  pkgs/main/linux-64        143 KB
#   mkl_random                                 1.1.1  py37h0573a6f_0                  pkgs/main/linux-64        322 KB
#   mock                                       4.0.2  py_0                            pkgs/main/noarch           32 KB
#   more-itertools                             8.4.0  py_0                            pkgs/main/noarch           42 KB
#   mpc                                        1.1.0  h10f8cd9_1                      pkgs/main/linux-64         90 KB
#   mpfr                                       4.0.2  hb69a4c5_1                      pkgs/main/linux-64        487 KB
#   mpmath                                     1.1.0  py37_0                          pkgs/main/linux-64        766 KB
#   msgpack-python                             1.0.0  py37hfd86e86_1                  pkgs/main/linux-64         89 KB
#   multipledispatch                           0.6.0  py37_0                          pkgs/main/linux-64         22 KB
#   nbconvert                                  5.6.1  py37_1                          pkgs/main/linux-64        451 KB
#   nbformat                                   5.0.7  py_0                            pkgs/main/noarch           89 KB
#   networkx                                     2.4  py_1                            pkgs/main/noarch            1 MB
#   ninja                                     1.10.0  py37hfd86e86_0                  pkgs/main/linux-64          1 MB
#   nltk                                         3.5  py_0                            pkgs/main/noarch          976 KB
#   nose                                       1.3.7  py37_1004                       pkgs/main/linux-64        214 KB
#   notebook                                   6.0.3  py37_0                          pkgs/main/linux-64          4 MB
#   numba                                     0.50.1  py37h0573a6f_1                  pkgs/main/linux-64          3 MB
#   numexpr                                    2.7.1  py37h423224d_0                  pkgs/main/linux-64        187 KB
#   numpy                                     1.18.5  py37ha1c710e_0                  pkgs/main/linux-64          5 KB
#   numpy-base                                1.18.5  py37hde5b4d6_0                  pkgs/main/linux-64          4 MB
#   numpydoc                                   1.1.0  py_0                            pkgs/main/noarch           42 KB
#   olefile                                     0.46  py37_0                          pkgs/main/linux-64         50 KB
#   openpyxl                                   3.0.4  py_0                            pkgs/main/noarch          157 KB
#   packaging                                   20.4  py_0                            pkgs/main/noarch           36 KB
#   pandas                                     1.0.5  py37h0573a6f_0                  pkgs/main/linux-64          8 MB
#   pandoc                                      2.10  0                               pkgs/main/linux-64         12 MB
#   pandocfilters                              1.4.2  py37_1                          pkgs/main/linux-64         13 KB
#   pango                                     1.45.3  hd140c19_0                      pkgs/main/linux-64        361 KB
#   parso                                      0.7.0  py_0                            pkgs/main/noarch           72 KB
#   partd                                      1.1.0  py_0                            pkgs/main/noarch           20 KB
#   patchelf                                    0.11  he6710b0_0                      pkgs/main/linux-64         75 KB
#   path                                      13.1.0  py37_0                          pkgs/main/linux-64         35 KB
#   path.py                                   12.4.0  0                               pkgs/main/noarch            7 KB
#   pathlib2                                   2.3.5  py37_1                          pkgs/main/linux-64         35 KB
#   pathtools                                  0.1.2  py_1                            pkgs/main/noarch           10 KB
#   patsy                                      0.5.1  py37_0                          pkgs/main/linux-64        274 KB
#   pcre                                        8.44  he6710b0_0                      pkgs/main/linux-64        212 KB
#   pep8                                       1.7.1  py37_0                          pkgs/main/linux-64         53 KB
#   pexpect                                    4.8.0  py37_1                          pkgs/main/linux-64         77 KB
#   pickleshare                                0.7.5  py37_1001                       pkgs/main/linux-64         13 KB
#   pillow                                     7.2.0  py37hb39fc2d_0                  pkgs/main/linux-64        617 KB
#   pixman                                    0.40.0  h7b6447c_0                      pkgs/main/linux-64        370 KB
# ...
# pycodestyle-2.6.0    | 43 KB     | : 100% 1.0/1 [00:00<00:00,  9.67it/s]
# ptyprocess-0.6.0     | 23 KB     | : 100% 1.0/1 [00:00<00:00,  8.63it/s]
# backports.shutil_get | 8 KB      | : 100% 1.0/1 [00:00<00:00,  9.51it/s]
# locket-0.2.0         | 9 KB      | : 100% 1.0/1 [00:00<00:00, 10.06it/s]
# pixman-0.40.0        | 370 KB    | : 100% 1.0/1 [00:00<00:00,  9.04it/s]
# jupyter_core-4.6.3   | 71 KB     | : 100% 1.0/1 [00:00<00:00, 10.67it/s]
# importlib_metadata-1 | 11 KB     | : 100% 1.0/1 [00:00<00:00, 12.23it/s]
# prompt_toolkit-3.0.5 | 11 KB     | : 100% 1.0/1 [00:00<00:00, 10.71it/s]
# pydocstyle-5.0.2     | 37 KB     | : 100% 1.0/1 [00:00<00:00, 10.41it/s]
# et_xmlfile-1.0.1     | 12 KB     | : 100% 1.0/1 [00:00<00:00, 11.20it/s]
# zlib-1.2.11          | 103 KB    | : 100% 1.0/1 [00:00<00:00, 11.87it/s]
# scipy-1.5.0          | 14.4 MB   | : 100% 1.0/1 [00:00<00:00,  1.07it/s]
# astroid-2.4.2        | 279 KB    | : 100% 1.0/1 [00:00<00:00,  6.70it/s]
# diff-match-patch-202 | 36 KB     | : 100% 1.0/1 [00:00<00:00,  3.55it/s]
# jupyterlab-2.1.5     | 3.3 MB    | : 100% 1.0/1 [00:00<00:00,  4.55it/s]
# libpng-1.6.37        | 278 KB    | : 100% 1.0/1 [00:00<00:00, 11.16it/s]
# lxml-4.5.2           | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  4.96it/s]
# libtool-2.4.6        | 389 KB    | : 100% 1.0/1 [00:00<00:00,  9.50it/s]
# python-3.7.7         | 45.1 MB   | : 100% 1.0/1 [00:01<00:00,  1.39s/it]
# xlrd-1.2.0           | 175 KB    | : 100% 1.0/1 [00:00<00:00,  9.83it/s]
# sphinxcontrib-jsmath | 9 KB      | : 100% 1.0/1 [00:00<00:00, 12.72it/s]
# autopep8-1.5.3       | 45 KB     | : 100% 1.0/1 [00:00<00:00, 11.68it/s]
# pyflakes-2.2.0       | 61 KB     | : 100% 1.0/1 [00:00<00:00, 10.10it/s]
# pandocfilters-1.4.2  | 13 KB     | : 100% 1.0/1 [00:00<00:00, 12.30it/s]
# argh-0.26.2          | 36 KB     | : 100% 1.0/1 [00:00<00:00, 11.76it/s]
# imagesize-1.2.0      | 10 KB     | : 100% 1.0/1 [00:00<00:00, 12.38it/s]
# psutil-5.7.0         | 319 KB    | : 100% 1.0/1 [00:00<00:00,  6.29it/s]
# sphinxcontrib-qthelp | 25 KB     | : 100% 1.0/1 [00:00<00:00, 10.22it/s]
# webencodings-0.5.1   | 19 KB     | : 100% 1.0/1 [00:00<00:00, 11.60it/s]
# sqlite-3.32.3        | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  6.53it/s]
# glob2-0.7            | 15 KB     | : 100% 1.0/1 [00:00<00:00, 12.17it/s]
# cycler-0.10.0        | 13 KB     | : 100% 1.0/1 [00:00<00:00, 12.25it/s]
# tbb-2020.0           | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  6.50it/s]
# blosc-1.19.0         | 71 KB     | : 100% 1.0/1 [00:00<00:00,  8.93it/s]
# pep8-1.7.1           | 53 KB     | : 100% 1.0/1 [00:00<00:00, 10.40it/s]
# pyodbc-4.0.30        | 70 KB     | : 100% 1.0/1 [00:00<00:00, 12.13it/s]
# pandoc-2.10          | 12.4 MB   | : 100% 1.0/1 [00:00<00:00,  1.31it/s]
# jupyter_console-6.1. | 24 KB     | : 100% 1.0/1 [00:00<00:00, 11.24it/s]
# libnghttp2-1.41.0    | 774 KB    | : 100% 1.0/1 [00:00<00:00,  4.00it/s]
# fastcache-1.1.0      | 30 KB     | : 100% 1.0/1 [00:00<00:00, 11.05it/s]
# gmpy2-2.0.8          | 150 KB    | : 100% 1.0/1 [00:00<00:00, 10.62it/s]
# future-0.18.2        | 631 KB    | : 100% 1.0/1 [00:00<00:00,  5.95it/s]
# pylint-2.5.3         | 441 KB    | : 100% 1.0/1 [00:00<00:00,  2.87it/s]
# send2trash-1.5.0     | 16 KB     | : 100% 1.0/1 [00:00<00:00,  9.90it/s]
# python-jsonrpc-serve | 11 KB     | : 100% 1.0/1 [00:00<00:00, 10.21it/s]
# pycparser-2.20       | 94 KB     | : 100% 1.0/1 [00:00<00:00, 10.69it/s]
# numpy-base-1.18.5    | 4.1 MB    | : 100% 1.0/1 [00:00<00:00,  3.23it/s]
# flask-1.1.2          | 78 KB     | : 100% 1.0/1 [00:00<00:00, 12.34it/s]
# beautifulsoup4-4.9.1 | 165 KB    | : 100% 1.0/1 [00:00<00:00,  9.04it/s]
# dbus-1.13.16         | 501 KB    | : 100% 1.0/1 [00:00<00:00,  8.34it/s]
# singledispatch-3.4.0 | 16 KB     | : 100% 1.0/1 [00:00<00:00,  9.41it/s]
# scikit-image-0.16.2  | 23.1 MB   | : 100% 1.0/1 [00:00<00:00,  1.38it/s]
# tqdm-4.47.0          | 62 KB     | : 100% 1.0/1 [00:00<00:00,  1.79it/s]
# distributed-2.20.0   | 992 KB    | : 100% 1.0/1 [00:00<00:00,  4.11it/s]
# sortedcollections-1. | 13 KB     | : 100% 1.0/1 [00:00<00:00,  8.57it/s]
# libcurl-7.71.1       | 305 KB    | : 100% 1.0/1 [00:00<00:00,  8.43it/s]
# babel-2.8.0          | 5.3 MB    | : 100% 1.0/1 [00:00<00:00,  2.94it/s]
# yaml-0.2.5           | 75 KB     | : 100% 1.0/1 [00:00<00:00, 12.08it/s]
# intervaltree-3.0.2   | 24 KB     | : 100% 1.0/1 [00:00<00:00, 12.00it/s]
# jsonschema-3.2.0     | 91 KB     | : 100% 1.0/1 [00:00<00:00, 10.67it/s]
# snappy-1.1.8         | 40 KB     | : 100% 1.0/1 [00:00<00:00, 10.85it/s]
# libstdcxx-ng-9.1.0   | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  5.13it/s]
# zict-2.0.0           | 13 KB     | : 100% 1.0/1 [00:00<00:00, 12.31it/s]
# ipykernel-5.3.2      | 179 KB    | : 100% 1.0/1 [00:00<00:00,  3.62it/s]
# xlwt-1.3.0           | 158 KB    | : 100% 1.0/1 [00:00<00:00, 10.81it/s]
# spyder-kernels-1.9.2 | 97 KB     | : 100% 1.0/1 [00:00<00:00,  3.60it/s]
# wheel-0.34.2         | 51 KB     | : 100% 1.0/1 [00:00<00:00,  9.42it/s]
# numpy-1.18.5         | 5 KB      | : 100% 1.0/1 [00:00<00:00,  9.34it/s]
# widgetsnbextension-3 | 862 KB    | : 100% 1.0/1 [00:00<00:00,  7.60it/s]
# zstd-1.4.5           | 464 KB    | : 100% 1.0/1 [00:00<00:00,  7.49it/s]
# rtree-0.9.4          | 47 KB     | : 100% 1.0/1 [00:00<00:00,  9.69it/s]
# ujson-1.35           | 25 KB     | : 100% 1.0/1 [00:00<00:00,  6.02it/s]
# pango-1.45.3         | 361 KB    | : 100% 1.0/1 [00:00<00:00, 10.36it/s]
# libtiff-4.1.0        | 449 KB    | : 100% 1.0/1 [00:00<00:00, 10.46it/s]
# pycurl-7.43.0.5      | 68 KB     | : 100% 1.0/1 [00:00<00:00,  8.32it/s]
# gstreamer-1.14.0     | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  3.35it/s]
# libedit-3.1.20191231 | 116 KB    | : 100% 1.0/1 [00:00<00:00, 11.33it/s]
# jedi-0.17.1          | 921 KB    | : 100% 1.0/1 [00:00<00:00,  3.02it/s]
# libuuid-1.0.3        | 15 KB     | : 100% 1.0/1 [00:00<00:00, 11.81it/s]
# markupsafe-1.1.1     | 26 KB     | : 100% 1.0/1 [00:00<00:00, 12.02it/s]
# joblib-0.16.0        | 210 KB    | : 100% 1.0/1 [00:00<00:00,  9.63it/s]
# docutils-0.16        | 660 KB    | : 100% 1.0/1 [00:00<00:00,  5.33it/s]
# patsy-0.5.1          | 274 KB    | : 100% 1.0/1 [00:00<00:00, 10.14it/s]
# multipledispatch-0.6 | 22 KB     | : 100% 1.0/1 [00:00<00:00, 10.32it/s]
# pytest-5.4.3         | 388 KB    | : 100% 1.0/1 [00:00<00:00,  3.80it/s]
# qt-5.9.7             | 68.5 MB   | : 100% 1.0/1 [00:03<00:00,  3.31s/it]
# typed-ast-1.4.1      | 183 KB    | : 100% 1.0/1 [00:00<00:00, 10.46it/s]
# sphinxcontrib-htmlhe | 27 KB     | : 100% 1.0/1 [00:00<00:00,  9.18it/s]
# libxml2-2.9.10       | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  5.62it/s]
# get_terminal_size-1. | 3 KB      | : 100% 1.0/1 [00:00<00:00, 11.39it/s]
# sphinxcontrib-devhel | 22 KB     | : 100% 1.0/1 [00:00<00:00,  8.86it/s]
# libspatialindex-1.9. | 2.1 MB    | : 100% 1.0/1 [00:00<00:00,  5.98it/s]
# py-1.9.0             | 79 KB     | : 100% 1.0/1 [00:00<00:00,  9.83it/s]
# harfbuzz-2.4.0       | 850 KB    | : 100% 1.0/1 [00:00<00:00,  4.56it/s]
# python-dateutil-2.8. | 215 KB    | : 100% 1.0/1 [00:00<00:00, 10.27it/s]
# wrapt-1.11.2         | 49 KB     | : 100% 1.0/1 [00:00<00:00,  9.43it/s]
# ipywidgets-7.5.1     | 104 KB    | : 100% 1.0/1 [00:00<00:00, 10.27it/s]
# h5py-2.10.0          | 1.0 MB    | : 100% 1.0/1 [00:00<00:00,  6.51it/s]
# mpfr-4.0.2           | 487 KB    | : 100% 1.0/1 [00:00<00:00,  7.63it/s]
# unixodbc-2.3.7       | 285 KB    | : 100% 1.0/1 [00:00<00:00, 10.05it/s]
# _libgcc_mutex-0.1    | 3 KB      | : 100% 1.0/1 [00:00<00:00,  9.85it/s]
# cffi-1.14.0          | 224 KB    | : 100% 1.0/1 [00:00<00:00, 11.00it/s]
# dask-core-2.20.0     | 590 KB    | : 100% 1.0/1 [00:00<00:00,  7.07it/s]
# unicodecsv-0.14.1    | 25 KB     | : 100% 1.0/1 [00:00<00:00, 11.83it/s]
# pip-20.1.1           | 1.7 MB    | : 100% 1.0/1 [00:00<00:00,  4.75it/s]
# libllvm9-9.0.1       | 21.0 MB   | : 100% 1.0/1 [00:00<00:00,  1.05it/s]
# fsspec-0.7.4         | 63 KB     | : 100% 1.0/1 [00:00<00:00,  2.02it/s]
# glib-2.65.0          | 2.9 MB    | : 100% 1.0/1 [00:00<00:00,  3.74it/s]
# boto-2.49.0          | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  4.93it/s]
# jupyter_client-6.1.6 | 84 KB     | : 100% 1.0/1 [00:00<00:00,  9.38it/s]
# parso-0.7.0          | 72 KB     | : 100% 1.0/1 [00:00<00:00, 11.30it/s]
# libffi-3.3           | 50 KB     | : 100% 1.0/1 [00:00<00:00,  9.86it/s]
# xlsxwriter-1.2.9     | 112 KB    | : 100% 1.0/1 [00:00<00:00, 10.90it/s]
# jupyter-1.0.0        | 6 KB      | : 100% 1.0/1 [00:00<00:00, 11.50it/s]
# icu-58.2             | 10.5 MB   | : 100% 1.0/1 [00:00<00:00,  1.67it/s]
# greenlet-0.4.16      | 24 KB     | : 100% 1.0/1 [00:00<00:00,  8.48it/s]
# brotlipy-0.7.0       | 322 KB    | : 100% 1.0/1 [00:00<00:00,  7.82it/s]
# ruamel_yaml-0.15.87  | 245 KB    | : 100% 1.0/1 [00:00<00:00,  4.47it/s]
# freetype-2.10.2      | 608 KB    | : 100% 1.0/1 [00:00<00:00,  1.44it/s]
# terminado-0.8.3      | 26 KB     | : 100% 1.0/1 [00:00<00:00, 11.75it/s]
# jdcal-1.4.1          | 11 KB     | : 100% 1.0/1 [00:00<00:00, 11.12it/s]
# bleach-3.1.5         | 116 KB    | : 100% 1.0/1 [00:00<00:00,  9.49it/s]
# sympy-1.6.1          | 8.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.05it/s]
# itsdangerous-1.1.0   | 28 KB     | : 100% 1.0/1 [00:00<00:00,  9.31it/s]
# requests-2.24.0      | 56 KB     | : 100% 1.0/1 [00:00<00:00, 11.58it/s]
# partd-1.1.0          | 20 KB     | : 100% 1.0/1 [00:00<00:00, 11.82it/s]
# mccabe-0.6.1         | 14 KB     | : 100% 1.0/1 [00:00<00:00, 10.80it/s]
# mkl_random-1.1.1     | 322 KB    | : 100% 1.0/1 [00:00<00:00, 10.18it/s]
# contextlib2-0.6.0.po | 16 KB     | : 100% 1.0/1 [00:00<00:00, 12.11it/s]
# openpyxl-3.0.4       | 157 KB    | : 100% 1.0/1 [00:00<00:00,  8.82it/s]
# blas-1.0             | 6 KB      | : 100% 1.0/1 [00:00<00:00, 12.10it/s]
# bzip2-1.0.8          | 78 KB     | : 100% 1.0/1 [00:00<00:00,  8.08it/s]
# python-language-serv | 81 KB     | : 100% 1.0/1 [00:00<00:00,  8.52it/s]
# zope-1.0             | 4 KB      | : 100% 1.0/1 [00:00<00:00, 11.20it/s]
# pyzmq-19.0.1         | 459 KB    | : 100% 1.0/1 [00:00<00:00,  6.79it/s]
# colorama-0.4.3       | 20 KB     | : 100% 1.0/1 [00:00<00:00, 11.32it/s]
# patchelf-0.11        | 75 KB     | : 100% 1.0/1 [00:00<00:00,  8.93it/s]
# pexpect-4.8.0        | 77 KB     | : 100% 1.0/1 [00:00<00:00,  9.81it/s]
# backcall-0.2.0       | 15 KB     | : 100% 1.0/1 [00:00<00:00, 11.71it/s]
# sphinx-3.1.2         | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  5.19it/s]
# qtpy-1.9.0           | 38 KB     | : 100% 1.0/1 [00:00<00:00, 10.91it/s]
# cudatoolkit-10.2.89  | 365.1 MB  | : 100% 1.0/1 [00:26<00:00, 26.03s/it]
# dask-2.20.0          | 4 KB      | : 100% 1.0/1 [00:00<00:00, 10.62it/s]
# xz-5.2.5             | 341 KB    | : 100% 1.0/1 [00:04<00:00,  4.88s/it]
# regex-2020.6.8       | 324 KB    | : 100% 1.0/1 [00:00<00:00, 10.45it/s]
# qdarkstyle-2.8.1     | 176 KB    | : 100% 1.0/1 [00:00<00:00, 10.56it/s]
# pathlib2-2.3.5       | 35 KB     | : 100% 1.0/1 [00:00<00:00,  7.96it/s]
# zope.event-4.4       | 10 KB     | : 100% 1.0/1 [00:00<00:00,  8.41it/s]
# fontconfig-2.13.0    | 227 KB    | : 100% 1.0/1 [00:00<00:00,  7.69it/s]
# anaconda-client-1.7. | 147 KB    | : 100% 1.0/1 [00:00<00:00,  6.42it/s]
# mkl-2020.1           | 129.0 MB  | : 100% 1.0/1 [00:19<00:00, 19.78s/it]
# ipython-7.16.1       | 987 KB    | : 100% 1.0/1 [00:00<00:00,  5.14it/s]
# ld_impl_linux-64-2.3 | 568 KB    | : 100% 1.0/1 [00:00<00:00,  8.60it/s]
# json5-0.9.5          | 22 KB     | : 100% 1.0/1 [00:00<00:00, 12.64it/s]
# krb5-1.18.2          | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  5.92it/s]
# gst-plugins-base-1.1 | 4.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.93s/it]
# mock-4.0.2           | 32 KB     | : 100% 1.0/1 [00:00<00:00, 12.80it/s]
# gmp-6.1.2            | 514 KB    | : 100% 1.0/1 [00:00<00:00, 10.22it/s]
# libgomp-9.3.0        | 311 KB    | : 100% 1.0/1 [00:00<00:00, 10.44it/s]
# jpeg-9b              | 214 KB    | : 100% 1.0/1 [00:00<00:00,  9.55it/s]
# mpmath-1.1.0         | 766 KB    | : 100% 1.0/1 [00:00<00:00,  7.79it/s]
# alabaster-0.7.12     | 18 KB     | : 100% 1.0/1 [00:00<00:00, 12.12it/s]
# libsolv-0.7.16       | 455 KB    | : 100% 1.0/1 [00:00<00:00,  7.70it/s]
# pycosat-0.6.3        | 82 KB     | : 100% 1.0/1 [00:00<00:00,  7.47it/s]
# curl-7.71.1          | 140 KB    | : 100% 1.0/1 [00:00<00:00,  8.96it/s]
# chardet-3.0.4        | 174 KB    | : 100% 1.0/1 [00:00<00:00,  7.90it/s]
# certifi-2020.6.20    | 156 KB    | : 100% 1.0/1 [00:00<00:00,  8.88it/s]
# setuptools-49.2.0    | 743 KB    | : 100% 1.0/1 [00:00<00:00,  5.77it/s]
# expat-2.2.9          | 156 KB    | : 100% 1.0/1 [00:00<00:00,  7.74it/s]
# sphinxcontrib-1.0    | 4 KB      | : 100% 1.0/1 [00:00<00:00, 10.76it/s]
# done
# done
# done
# | Ran pip subprocess with arguments:
# ['/usr/local/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/drive/.shortcut-targets-by-id/1ToHnZjx6MmCRPAtxDUrirVP51cZnbzgo/fang/condaenv.csqqcz6h.requirements.txt']
# Pip subprocess output:
# Collecting absl-py==0.9.0
#   Downloading absl-py-0.9.0.tar.gz (104 kB)
# Collecting grpcio==1.31.0
#   Downloading grpcio-1.31.0-cp37-cp37m-manylinux2014_x86_64.whl (3.4 MB)
# Collecting markdown==3.2.2
#   Downloading Markdown-3.2.2-py3-none-any.whl (88 kB)
# Collecting protobuf==3.13.0
#   Downloading protobuf-3.13.0-cp37-cp37m-manylinux1_x86_64.whl (1.3 MB)
# Collecting tensorboard==1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/site-packages (from absl-py==0.9.0->-r /content/drive/.shortcut-targets-by-id/1ToHnZjx6MmCRPAtxDUrirVP51cZnbzgo/fang/condaenv.csqqcz6h.requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from markdown==3.2.2->-r /content/drive/.shortcut-targets-by-id/1ToHnZjx6MmCRPAtxDUrirVP51cZnbzgo/fang/condaenv.csqqcz6h.requirements.txt (line 3)) (1.7.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.7/site-packages (from protobuf==3.13.0->-r /content/drive/.shortcut-targets-by-id/1ToHnZjx6MmCRPAtxDUrirVP51cZnbzgo/fang/condaenv.csqqcz6h.requirements.txt (line 4)) (49.2.0.post20200714)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.7/site-packages (from tensorboard==1.15.0->-r /content/drive/.shortcut-targets-by-id/1ToHnZjx6MmCRPAtxDUrirVP51cZnbzgo/fang/condaenv.csqqcz6h.requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/site-packages (from tensorboard==1.15.0->-r /content/drive/.shortcut-targets-by-id/1ToHnZjx6MmCRPAtxDUrirVP51cZnbzgo/fang/condaenv.csqqcz6h.requirements.txt (line 5)) (0.34.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.12.0 in /usr/local/lib/python3.7/site-packages (from tensorboard==1.15.0->-r /content/drive/.shortcut-targets-by-id/1ToHnZjx6MmCRPAtxDUrirVP51cZnbzgo/fang/condaenv.csqqcz6h.requirements.txt (line 5)) (1.18.5)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown==3.2.2->-r /content/drive/.shortcut-targets-by-id/1ToHnZjx6MmCRPAtxDUrirVP51cZnbzgo/fang/condaenv.csqqcz6h.requirements.txt (line 3)) (3.1.0)
# Building wheels for collected packages: absl-py
#   Building wheel for absl-py (setup.py): started
#   Building wheel for absl-py (setup.py): finished with status 'done'
#   Created wheel for absl-py: filename=absl_py-0.9.0-py3-none-any.whl size=121931 sha256=5ff8b56377be199b20a0cd5105a38d1b1cae91d455533a13bf8b108d7888be74
#   Stored in directory: /root/.cache/pip/wheels/cc/af/1a/498a24d0730ef484019e007bb9e8cef3ac00311a672c049a3e
# Successfully built absl-py
# Installing collected packages: absl-py, grpcio, markdown, protobuf, tensorboard
# Successfully installed absl-py-0.9.0 grpcio-1.31.0 markdown-3.2.2 protobuf-3.13.0 tensorboard-1.15.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate base
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %% [markdown]
# ## 6. Train and evaluate model (or, at least try to 😀)

# %% [markdown]
# For example, we can try to execute the first command mentioned in FANG's [GitHub repo](https://github.com/nguyenvanhoang7398/FANG.git). Unfortunately, we didn't manage to get this code to finish execution. It seems that the Colab machine runs out of RAM and then the script is silently killed. We cannot verify this properly though, as one cannot inspect the system resources usage at the same level of detail as when running code locally on one's own machine.

# %%
# !python run_graph.py -t fang -m graph_sage -p data/news_graph --percent 90 --epochs=30 --attention --use-stance --use-proximity --temporal
# Out:
# Using stance
# Using proximity
# Load FANG dataset from data/news_graph
# /content/drive/.shortcut-targets-by-id/1ToHnZjx6MmCRPAtxDUrirVP51cZnbzgo/fang/fang/utils.py:98: RuntimeWarning: divide by zero encountered in power
#   sum_inv = np.power(row_sum, -1).flatten()
# Creating new far node cache with capacity 20000
# Use temporal
# Initialize optimizer with weight decay 0.0005
# Train 55858 Dev 51 Test 48
# Training GraphSage:   0% 0/30 [00:00<?, ?it/s]
# Sampling news batches:   0% 0/47 [00:00<?, ?it/s]tcmalloc: large alloc 1767661568 bytes == 0x5559f9df6000 @  0x7f668cc40b6b 0x7f668cc60379 0x7f663635acc7 0x7f663635d21a 0x7f6662290e4c 0x7f66624fa4cb 0x7f66624ec677 0x7f66624ec339 0x7f66624ec677 0x7f666229860e 0x7f666229cecd 0x7f66625b77e3 0x7f66624eca29 0x7f66624ea012 0x7f66624eca29 0x7f666761a422 0x7f666749d1fd 0x555956777c94 0x555956777db1 0x5559567e35be 0x555956727b00 0x555956777497 0x5559567e3229 0x5559567272b9 0x5559567283e5 0x555956746b93 0x55595673995e 0x5559567e051a 0x5559567272b9 0x5559567283e5 0x555956746b93
# tcmalloc: large alloc 1767661568 bytes == 0x555ab0192000 @  0x7f668cc40b6b 0x7f668cc60379 0x7f663635acc7 0x7f663635d21a 0x7f6662290e4c 0x7f66624fa4cb 0x7f66624ec677 0x7f66624ec339 0x7f66624ec677 0x7f66622b33be 0x7f66622b38dc 0x7f66622b4cb8 0x7f66622b51a6 0x7f6661fd3ecc 0x7f66624f5eb8 0x7f666253ae70 0x7f66641166fe 0x7f666253ae70 0x7f666747f5b3 0x7f6667413158 0x555956777c94 0x55595677eaef 0x5559567e337c 0x555956727b00 0x555956777497 0x5559567e3229 0x5559567272b9 0x5559567283e5 0x555956746b93 0x55595673995e 0x5559567e051a
# {'grad': 1.98629891872406, 'context_loss': 7.8915696144104, 'stance_loss': 1.3760079145431519, 'news_loss': 0.6879884600639343}
#
#
# Validating rep learning:   0% 0/2211 [00:00<?, ?it/s]
#
# Validating rep learning:   7% 148/2211 [00:00<00:01, 1475.67it/s]
#
# Validating rep learning:  15% 329/2211 [00:00<00:01, 1560.28it/s]
#
# Validating rep learning:  22% 482/2211 [00:00<00:01, 1548.51it/s]
#
# Validating rep learning:  29% 647/2211 [00:00<00:00, 1576.39it/s]
#
# Validating rep learning:  36% 789/2211 [00:00<00:00, 1522.81it/s]
#
# Validating rep learning:  42% 932/2211 [00:00<00:00, 1491.03it/s]
#
# Validating rep learning:  49% 1088/2211 [00:00<00:00, 1509.23it/s]
#
# Validating rep learning:  56% 1245/2211 [00:00<00:00, 1525.90it/s]
#
# Validating rep learning:  63% 1394/2211 [00:00<00:00, 1512.88it/s]
#
# Validating rep learning:  70% 1544/2211 [00:01<00:00, 1508.45it/s]
#
# Validating rep learning:  77% 1701/2211 [00:01<00:00, 1523.30it/s]
#
# Validating rep learning:  84% 1853/2211 [00:01<00:00, 1521.62it/s]
#
# Validating rep learning:  91% 2004/2211 [00:01<00:00, 1506.00it/s]
#
# Validating rep learning: 100% 2211/2211 [00:01<00:00, 1519.56it/s]
# {'stance_avg_closed_ratio': 0.9605157560020502, 'stance_avg_far_ratio': 0.9854606374796709, 'other_avg_closed_ratio': 0.9769336838814712, 'other_avg_far_ratio': 0.0}
#
# Sampling news batches:   2% 1/47 [02:30<1:55:13, 150.29s/it]tcmalloc: large alloc 1848279040 bytes == 0x5559f9acc000 @  0x7f668cc40b6b 0x7f668cc60379 0x7f663635acc7 0x7f663635d21a 0x7f6662290e4c 0x7f66624fa4cb 0x7f66624ec677 0x7f66624ec339 0x7f66624ec677 0x7f666229860e 0x7f666229cecd 0x7f66625b77e3 0x7f66624eca29 0x7f66624ea012 0x7f66624eca29 0x7f666761a422 0x7f666749d1fd 0x555956777c94 0x555956777db1 0x5559567e35be 0x555956727b00 0x555956777497 0x5559567e3229 0x5559567272b9 0x5559567283e5 0x555956746b93 0x55595673995e 0x5559567e051a 0x5559567272b9 0x5559567283e5 0x555956746b93
# tcmalloc: large alloc 1848279040 bytes == 0x555ac410e000 @  0x7f668cc40b6b 0x7f668cc60379 0x7f663635acc7 0x7f663635d21a 0x7f6662290e4c 0x7f66624fa4cb 0x7f66624ec677 0x7f66624ec339 0x7f66624ec677 0x7f66622b33be 0x7f66622b38dc 0x7f66622b4cb8 0x7f66622b51a6 0x7f6661fd3ecc 0x7f66624f5eb8 0x7f666253ae70 0x7f66641166fe 0x7f666253ae70 0x7f666747f5b3 0x7f6667413158 0x555956777c94 0x55595677eaef 0x5559567e337c 0x555956727b00 0x555956777497 0x5559567e3229 0x5559567272b9 0x5559567283e5 0x555956746b93 0x55595673995e 0x5559567e051a
#
# Sampling news batches:   4% 2/47 [03:44<1:35:37, 127.50s/it]tcmalloc: large alloc 1950703616 bytes == 0x555a0bb70000 @  0x7f668cc40b6b 0x7f668cc60379 0x7f663635acc7 0x7f663635d21a 0x7f6662290e4c 0x7f66624fa4cb 0x7f66624ec677 0x7f66624ec339 0x7f66624ec677 0x7f666229860e 0x7f666229cecd 0x7f66625b77e3 0x7f66624eca29 0x7f66624ea012 0x7f66624eca29 0x7f666761a422 0x7f666749d1fd 0x555956777c94 0x555956777db1 0x5559567e35be 0x555956727b00 0x555956777497 0x5559567e3229 0x5559567272b9 0x5559567283e5 0x555956746b93 0x55595673995e 0x5559567e051a 0x5559567272b9 0x5559567283e5 0x555956746b93
# tcmalloc: large alloc 1950703616 bytes == 0x555ac3d2c000 @  0x7f668cc40b6b 0x7f668cc60379 0x7f663635acc7 0x7f663635d21a 0x7f6662290e4c 0x7f66624fa4cb 0x7f66624ec677 0x7f66624ec339 0x7f66624ec677 0x7f66622b33be 0x7f66622b38dc 0x7f66622b4cb8 0x7f66622b51a6 0x7f6661fd3ecc 0x7f66624f5eb8 0x7f666253ae70 0x7f66641166fe 0x7f666253ae70 0x7f666747f5b3 0x7f6667413158 0x555956777c94 0x55595677eaef 0x5559567e337c 0x555956727b00 0x555956777497 0x5559567e3229 0x5559567272b9 0x5559567283e5 0x555956746b93 0x55595673995e 0x5559567e051a
#
# Sampling news batches:   6% 3/47 [04:55<1:21:00, 110.47s/it]
# Sampling news batches:   9% 4/47 [05:59<1:09:12, 96.58s/it]
# Sampling news batches:  11% 5/47 [06:59<59:50, 85.50s/it]
# Sampling news batches:  13% 6/47 [08:00<53:24, 78.16s/it]
# Sampling news batches:  15% 7/47 [09:08<50:09, 75.23s/it]
# Sampling news batches:  17% 8/47 [10:01<44:31, 68.50s/it]
# Sampling news batches:  19% 9/47 [10:52<40:10, 63.42s/it]
# Sampling news batches:  21% 10/47 [11:43<36:47, 59.65s/it]
# Sampling news batches:  23% 11/47 [12:35<34:18, 57.19s/it]
# Sampling news batches:  26% 12/47 [13:32<33:21, 57.18s/it]
# Sampling news batches:  28% 13/47 [14:31<32:43, 57.76s/it]
# Sampling news batches:  30% 14/47 [15:28<31:41, 57.63s/it]
# Sampling news batches:  32% 15/47 [16:23<30:19, 56.86s/it]
# Sampling news batches:  34% 16/47 [17:25<30:07, 58.32s/it]
# Sampling news batches:  36% 17/47 [18:26<29:30, 59.02s/it]
# Sampling news batches:  38% 18/47 [19:20<27:46, 57.47s/it]^C

# %% [markdown]
# ## 7. (Bonus Tip) Keep Colab busy so runtime doesn't disconnect

# %% [markdown]
# Schedule execution of this cell after starting fitting a model so that the Colab runtime remains busy and doesn't disconnect due to being idle for too long.

# %%
while True:pass
